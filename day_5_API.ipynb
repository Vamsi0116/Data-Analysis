# %% [markdown]
# **Random Fox API**

# %%
import requests

# %%
page=requests.get('https://randomfox.ca/floof')

# %%
print(page.status_code)
# Out:
# 200

# %%
print(page.text)
# Out:
# {"image":"https:\/\/randomfox.ca\/images\/83.jpg","link":"https:\/\/randomfox.ca\/?i=83"}

# %%
print(page.json())
# Out:
# {'image': 'https://randomfox.ca/images/83.jpg', 'link': 'https://randomfox.ca/?i=83'}

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'e0e7db51-72de-483c-937c-3b2c5261dab7',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-16T09:48:58.898Z', 'error_code': 0, 'error_message': None, 'elapsed': 1, 'credit_count': 1, 'notice': None}, 'data': [{'id': 463, 'name': 'mfujldqo0v', 'symbol': '4nabgw3wo9', 'slug': '2gbetzfu7bl', 'cmc_rank': 7331, 'num_market_pairs': 4696, 'circulating_supply': 740, 'total_supply': 3992, 'max_supply': 1247, 'infinite_supply': None, 'last_updated': '2024-02-16T09:48:58.898Z', 'date_added': '2024-02-16T09:48:58.898Z', 'tags': ['b16aszxu264', 'xwyd124acnq', '8ovb8diofgn', 'aqt9przg2lp', 'ts45guwh1x', '5udm9amnnv7', '8tqn7bhxpae', '5dt2xkrjqoc', 'qisldlzv4ng', 'wargjjo9af'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.93174966782772, 'volume_24h': 8941, 'volume_change_24h': 0.9246802212891541, 'percent_change_1h': 0.3764460571129917, 'percent_change_24h': 0.03982073387468055, 'percent_change_7d': 0.2817609469898106, 'market_cap': 0.679051391676037, 'market_cap_dominance': 3321, 'fully_diluted_market_cap': 0.2291470479637443, 'last_updated': '2024-02-16T09:48:58.898Z'}}}, {'id': 4474, 'name': '6il3tfgjze5', 'symbol': '0snmra6aqjb', 'slug': '34vvgexy2vn', 'cmc_rank': 5533, 'num_market_pairs': 9075, 'circulating_supply': 5830, 'total_supply': 396, 'max_supply': 94, 'infinite_supply': None, 'last_updated': '2024-02-16T09:48:58.898Z', 'date_added': '2024-02-16T09:48:58.898Z', 'tags': ['r2vwdir2ain', 'ywxfj8b9ap', '7wt544jcc3x', 'ijko2cb7wns', 'pn95k2ujzpc', 'bjh3zqvv56', 'yhshrwmsjem', '8e27955jane', 'jpp18fenk4', 'm4aezpvsaj'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.11910558449901276, 'volume_24h': 9503, 'volume_change_24h': 0.09747600078125407, 'percent_change_1h': 0.30269976274581434, 'percent_change_24h': 0.9973312219820452, 'percent_change_7d': 0.8193352686122348, 'market_cap': 0.3266769039035051, 'market_cap_dominance': 6895, 'fully_diluted_market_cap': 0.4400064440019378, 'last_updated': '2024-02-16T09:48:58.898Z'}}}, {'id': 9633, 'name': '2ebd4q8yjah', 'symbol': 'il77v7xiroo', 'slug': '80n21qwmj6m', 'cmc_rank': 7496, 'num_market_pairs': 4713, 'circulating_supply': 973, 'total_supply': 4880, 'max_supply': 8178, 'infinite_supply': None, 'last_updated': '2024-02-16T09:48:58.898Z', 'date_added': '2024-02-16T09:48:58.898Z', 'tags': ['czw5pzgndda', '83slgqtjv5c', 'gmo5pjvqabn', 'fs30u1b8zkm', '29jqf2qtfw2', '8r297jjsm0x', '914dbpgq6xv', '357dyg067mc', '46tmx6ktr3n', 'plp6tm7zeg'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.1879859696004409, 'volume_24h': 6725, 'volume_change_24h': 0.5528215252302249, 'percent_change_1h': 0.3503112159738069, 'percent_change_24h': 0.9414797002335902, 'percent_change_7d': 0.8947811488635173, 'market_cap': 0.2642578294960194, 'market_cap_dominance': 5449, 'fully_diluted_market_cap': 0.287387192847232, 'last_updated': '2024-02-16T09:48:58.898Z'}}}, {'id': 5872, 'name': '3b3gw7eu0zq', 'symbol': 'xyn0957cjs', 'slug': '3t9z9clqp15', 'cmc_rank': 3871, 'num_market_pairs': 5062, 'circulating_supply': 917, 'total_supply': 6182, 'max_supply': 9337, 'infinite_supply': None, 'last_updated': '2024-02-16T09:48:58.898Z', 'date_added': '2024-02-16T09:48:58.898Z', 'tags': ['qddcvpt362', '74xnnd13ncx', '5qbsbjscojj', 'xjx11dpf4o', 'ursdia2cy0s', 'n43b7dqf4yf', 'cgpnbpwojlu', 'k8n4d7ltjwm', 'xenp7en17n', 'az46l53p8in'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.8423524443785699, 'volume_24h': 4785, 'volume_change_24h': 0.5576261449114659, 'percent_change_1h': 0.22321794060835098, 'percent_change_24h': 0.5359549814899818, 'percent_change_7d': 0.3557873866596857, 'market_cap': 0.10403559008184415, 'market_cap_dominance': 48, 'fully_diluted_market_cap': 0.16321829100369634, 'last_updated': '2024-02-16T09:48:58.898Z'}}}, {'id': 6300, 'name': 'nen7yva8xaf', 'symbol': 'grvu ...

# %%
import pandas as pd
norm=pd.json_normalize(data['data'])

# %%
norm
# Out:
#      id         name       symbol          slug  cmc_rank  num_market_pairs  \
# 0   463   mfujldqo0v   4nabgw3wo9   2gbetzfu7bl      7331              4696
# 1  4474  6il3tfgjze5  0snmra6aqjb   34vvgexy2vn      5533              9075
# 2  9633  2ebd4q8yjah  il77v7xiroo   80n21qwmj6m      7496              4713
# 3  5872  3b3gw7eu0zq   xyn0957cjs   3t9z9clqp15      3871              5062
# 4  6300  nen7yva8xaf  grvu03fy4v4    ifcriawnj1      1207              8745
# 5  5345  hcvugkg28rj  2pz66w5zjpq  069s8zn0mp5e      3080               994
# 6   542  5fa18c7lkc8   eo89s40idr  0uhuu0isc0sa       304              4750
# 7  8787  nd8k1djpr4n   yhu0kayj6t   gn1h2b8bpf5       572              2209
# 8  7969  ahiou9lcn2u  tx54r5fa40n   h8u4o9bdtaf      2204              9319
# 9  8073  nxa2zxdozzn  o9yg8sdo6f9   mqjblx9766a      3854               687
#
#    circulating_supply  total_supply  max_supply infinite_supply  ...  \
# 0                 740          3992        1247            None  ...
# 1                5830           396          94            None  ...
# 2                 973          4880        8178            None  ...
# 3                 917          6182        9337            None  ...
# 4                 406          8929        2292            None  ...
# 5                9124           110        2830            None  ...
# 6                2194          1825        8825            None  ...
# 7                8397          7791        8515            None  ...
# 8                 631          2908        9035            None  ...
# 9                3245          4733        9874            None  ...
#
#   quote.USD.price quote.USD.volume_24h quote.USD.volume_change_24h  \
# 0        0.931750                 8941                    0.924680
# 1        0.119106                 9503                    0.097476
# 2        0.187986                 6725                    0.552822
# 3        0.842352                 4785                    0.557626
# 4        0.041786                  403                    0.855040
# 5        0.354783                 9991                    0.080352
# 6        0.446054                 6136                    0.704786
# 7        0.174594                 8635                    0.414262
# 8        0.005497                 8251                    0.823854
# 9        0.413594                 5538                    0.517285
#
#   quote.USD.percent_change_1h quote.USD.percent_change_24h  \
# 0                    0.376446                     0.039821
# 1                    0.302700                     0.997331
# 2                    0.350311                     0.941480
# 3                    0.223218                     0.535955
# 4                    0.983038                     0.736289
# 5                    0.874114                     0.998317
# 6                    0.356970                     0.362623
# 7                    0.311954                     0.346879
# 8                    0.632973                     0.214159
# 9                    0.730562                     0.220519
#
#   quote.USD.percent_change_7d  quote.USD.market_cap  \
# 0                    0.281761              0.679051
# 1                    0.819335              0.326677
# 2                    0.894781              0.264258
# 3                    0.355787              0.104036
# 4                    0.355160              0.104461
# 5                    0.492176              0.642940
# 6                    0.325572              0.596575
# 7                    0.080450              0.211776
# 8                    0.067883              0.209378
# 9                    0.392270              0.520639
#
#    quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                            3321                            0.229147
# 1                            6895                            0.440006
# 2                            5449                            0.287387
# 3                              48                            0.163218
# 4                            8855                            0.144759
# 5                            7575                            0.282554
# 6                            8291                            0.287862
# 7                              29                            0.096290
# 8                            4951                            0.800627
# 9                            1759                            0.600420
#
#      quote.USD.last_updated
# 0  2024-02-16T09:48:58.898Z
# 1  2024-02-16T09:48:58.898Z
# 2  2024-02-16T09:48:58.898Z
# 3  2024-02-16T09:48:58.898Z
# 4  2024-02-16T09:48:58.898Z
# 5  2024-02-16T09:48:58.898Z
# 6  2024-02-16T09:48:58.898Z
# 7  2024-02-16T09:48:58.898Z
# 8  2024-02-16T09:48:58.898Z
# 9  2024-02-16T09:48:58.898Z
#
# [10 rows x 26 columns]

# %% [markdown]
# |
